# %%
import utils
from core import data 
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# using ImageNet normalization

# %%
data_dir = "../../different_cards"

data_handler = data.CardDataHandler(data_dir, uniform_sampling=True)
# Out:
# 13 validation split from training
# 115 training remains

# %%
trainloader, valloader = data_handler.get_dataloaders()
# Out:
# using ImageNet normalization
# created uniform sampler

# %%
utils.plot_ds(trainloader.dataset)

# %%
utils.plot_ds(valloader.dataset)

# %%
# check image size, and batch size 
for image, label in trainloader:
    print(label.shape)
    print(image.shape)
    break
# Out:
# torch.Size([16])
# torch.Size([16, 3, 128, 128])

# %%
# check the testloader as well
data_dir = "../../different_cards"
txt_fname = "data.txt"
data_handler = data.CardTestDataHandler(data_dir, txt_fname)

# %%
testloader = data_handler.get_testloader()
# Out:
# using ImageNet normalization

# %%
# %matplotlib inline 
for img, disp_img, label in testloader:
    plt.imshow(disp_img[0])
    plt.title(label[0])
    break
